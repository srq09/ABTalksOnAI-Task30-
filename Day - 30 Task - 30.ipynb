# %%
# ABTalks Season-3 Day-30
# Prompt Engineering Project

from openai import OpenAI, RateLimitError

# APNI API KEY YAHA PASTE KAREIN
API_KEY = "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"

client = OpenAI(api_key=API_KEY)

sample_text = """
Artificial Intelligence (AI) is transforming industries worldwide.
Healthcare uses AI for disease prediction and diagnosis.
Finance uses AI for fraud detection and automated trading.
Education uses AI for personalized learning.
Prompt engineering improves AI output quality through better instructions.
"""

def get_ai_response(system_role, user_prompt):
    try:
        response = client.chat.completions.create(
            model="gpt-4o-mini",
            messages=[
                {"role": "system", "content": system_role},
                {"role": "user", "content": user_prompt}
            ],
            temperature=0.3
        )
        return response.choices[0].message.content

    except RateLimitError:
        return "Rate limit exceeded. Check billing/quota."

    except Exception as e:
        return f"Error: {e}"

# SUMMARIZATION TASK
summary_prompt = f"""
You are a professional summarization expert.

Summarize the following content in 5 bullet points:

{sample_text}
"""

summary = get_ai_response(
    "You are an expert summarization assistant.",
    summary_prompt
)

print("="*60)
print("SUMMARIZATION OUTPUT")
print("="*60)
print(summary)

# Q&A TASK
qa_prompt = f"""
Answer these questions based only on the text below:

Text:
{sample_text}

Questions:
1. Which industries use AI?
2. How does AI help healthcare?
3. Why is prompt engineering important?
"""

qa = get_ai_response(
    "You are an expert Q&A assistant.",
    qa_prompt
)

print("\n" + "="*60)
print("Q&A OUTPUT")
print("="*60)
print(qa)

# OBSERVATIONS
print("\n" + "="*60)
print("OBSERVATIONS")
print("="*60)

observations = [
    "Clear prompts improve output quality.",
    "Structured instructions give more accurate responses.",
    "Prompt engineering directly impacts AI performance."
]

for obs in observations:
    print("•", obs)

print("\nTask Day-30 Completed Successfully")
# Out:
# ...
# SUMMARIZATION OUTPUT
# ...
# Rate limit exceeded. Check billing/quota.
#
# ...
# Q&A OUTPUT
# ...
# Rate limit exceeded. Check billing/quota.
#
# ...
# OBSERVATIONS
# ...
# • Clear prompts improve output quality.
# • Structured instructions give more accurate responses.
# • Prompt engineering directly impacts AI performance.
#
# Task Day-30 Completed Successfully
